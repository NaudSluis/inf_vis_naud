# %% [markdown]
# # Example Notebook
#
# (Last updated: May 22, 2023)
#
# You can also create content with Jupyter Notebooks.
# This means that you can include code blocks and their outputs in your book.
# In this notebook, we show some examples of loading and plotting data.
# Check [this documentation](https://jupyterbook.org/en/stable/content/executable/index.html) about how to write executable content.

# %%
# Import packages
import pandas as pd
import plotly.express as px
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### CBS-data 2016 pre-processing

# %%
import csv

input_file = "Leefstijl__persoonskenmerken_2016.csv"
output_file = "cbs_2016.csv"

with open(input_file, "r") as file:
    reader = csv.reader(file, delimiter=";")
    rows = list(reader)

with open(output_file, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(rows)

# %% [markdown]
# ### CBS-data 2022 pre-processing

# %%
import csv

input_file = "Leefstijl__persoonskenmerken_2022.csv"
output_file = "cbs_2022.csv"

with open(input_file, "r") as file:
    reader = csv.reader(file, delimiter=";")
    rows = list(reader)

with open(output_file, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(rows)

# %% [markdown]
# ### CBS-data year column

# %%
df_2022 = pd.read_csv('cbs_2022.csv')
df_2022['year'] = 2022
df_2022.to_csv('cbs_2022.csv', index=False)


df_2016 = pd.read_csv('cbs_2016.csv')
df_2016['year'] = 2016
df_2016.to_csv('cbs_2016.csv', index=False)

# %% [markdown]
# ### CBS-data merge

# %%
df_cbs = pd.concat([df_2016, df_2022], ignore_index=True)
df_cbs
# Out:
#     Alcoholgebruik, 12 jaar of ouder|Drinkers|Glazen alcohol per dag per drinker  \
# 0                                               aantal
# 1                                                  1,2
# 2                                                  1,5
# 3                                                  0,9
# 4                                                    .
# ..                                                 ...
# 103                                                1,0
# 104                                                1,0
# 105                                                1,0
# 106                                                1,2
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Cannabisgebruik|Afgelopen maand  \
# 0                                                    %
# 1                                                  3,9
# 2                                                  5,7
# 3                                                  2,2
# 4                                                    .
# ..                                                 ...
# 103                                                5,3
# 104                                                4,5
# 105                                                3,7
# 106                                                2,6
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Cannabisgebruik|Afgelopen jaar  \
# 0                                                    %
# 1                                                  6,5
# 2                                                  8,6
# 3                                                  4,4
# 4                                                    .
# ..                                                 ...
# 103                                                8,8
# 104                                                6,6
# 105                                                6,3
# 106                                                5,4
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Cannabisgebruik|Ooit  \
# 0                                                    %
# 1                                                 19,7
# 2                                                 23,7
# 3                                                 15,9
# 4                                                    .
# ..                                                 ...
# 103                                               22,8
# 104                                               21,0
# 105                                               22,4
# 106                                               19,5
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Amfetaminegebruik|Afgelopen maand  \
# 0                                                    %
# 1                                                  0,5
# 2                                                  0,8
# 3                                                  0,2
# 4                                                    .
# ..                                                 ...
# 103                                                0,3
# 104                                                0,9
# 105                                                0,5
# 106                                                0,2
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Amfetaminegebruik|Afgelopen jaar  \
# 0                                                    %
# 1                                                  1,3
# 2                                                  1,9
# 3                                                  0,7
# 4                                                    .
# ..                                                 ...
# 103                                                1,4
# 104                                                1,5
# 105                                                1,0
# 106                                                1,0
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Amfetaminegebruik|Ooit  \
# 0                                                    %
# 1                                                  4,1
# 2                                                  5,8
# 3                                                  2,4
# 4                                                    .
# ..                                                 ...
# 103                                                5,0
# 104                                                4,9
# 105                                                3,8
# 106                                                3,6
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Ecstasygebruik|Afgelopen maand  \
# 0                                                    %
# 1                                                  0,9
# 2                                                  1,3
# 3                                                  0,6
# 4                                                    .
# ..                                                 ...
# 103                                                0,8
# 104                                                1,3
# 105                                                1,3
# 106                                                1,1
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Ecstasygebruik|Afgelopen jaar  \
# 0                                                    %
# 1                                                  2,7
# 2                                                  3,5
# 3                                                  2,0
# 4                                                    .
# ..                                                 ...
# 103                                                3,2
# 104                                                3,1
# 105                                                3,6
# 106                                                3,7
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Ecstasygebruik|Ooit  \
# 0                                                    %
# 1                                                  7,0
# 2                                                  8,7
# 3                                                  5,3
# 4                                                    .
# ..                                                 ...
# 103                                                8,7
# 104                                                8,6
# 105                                                9,9
# 106                                                8,3
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Cocaïnegebruik|Afgelopen maand  \
# 0                                                    %
# 1                                                  0,7
# 2                                                  1,1
# 3                                                  0,3
# 4                                                    .
# ..                                                 ...
# 103                                                0,7
# 104                                                0,6
# 105                                                0,9
# 106                                                0,9
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Cocaïnegebruik|Afgelopen jaar  \
# 0                                                    %
# 1                                                  1,6
# 2                                                  2,4
# 3                                                  0,8
# 4                                                    .
# ..                                                 ...
# 103                                                1,8
# 104                                                1,7
# 105                                                2,2
# 106                                                2,2
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Cocaïnegebruik|Ooit  \
# 0                                                    %
# 1                                                  4,5
# 2                                                  6,5
# 3                                                  2,6
# 4                                                    .
# ..                                                 ...
# 103                                                5,5
# 104                                                5,1
# 105                                                5,7
# 106                                                5,1
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Gebruik overige drugs|Afgelopen maand  \
# 0                                                    %
# 1                                                  0,7
# 2                                                  1,1
# 3                                                  0,3
# 4                                                    .
# ..                                                 ...
# 103                                                1,0
# 104                                                0,7
# 105                                                0,6
# 106                                                0,6
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Gebruik overige drugs|Afgelopen jaar  \
# 0                                                    %
# 1                                                  1,5
# 2                                                  2,2
# 3                                                  0,8
# 4                                                    .
# ..                                                 ...
# 103                                                2,9
# 104                                                1,4
# 105                                                1,8
# 106                                                1,8
# 107                                                NaN
#
#     Drugsgebruik, 12 jaar of ouder|Gebruik overige drugs|Ooit  year
# 0                                                    %         2016
# 1                                                  5,0         2016
# 2                                                  6,9         2016
# 3                                                  3,1         2016
# 4                                                    .         2016
# ..                                                 ...          ...
# 103                                                7,0         2022
# 104                                                6,9         2022
# 105                                                6,8         2022
# 106                                                5,7         2022
# 107                                                NaN         2022
#
# [108 rows x 17 columns]
